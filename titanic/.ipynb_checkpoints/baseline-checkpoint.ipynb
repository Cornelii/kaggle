# %% [markdown]
# # Predict survivor in the titanic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=1.5)

# %matplotlib inline

# %%
df_train=pd.read_csv('./data/train.csv')
df_test=pd.read_csv('./data/test.csv')

# %%
df_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Null data check

# %% [markdown]
# ## train set

# %%
for col in df_train.columns:
    percent=100*(df_train[col].isnull().sum()/df_train[col].shape[0])
    msg="column: {}\t Percent of NaN value: {:.2f}".format(col,percent)
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00
# column: Survived	 Percent of NaN value: 0.00
# column: Pclass	 Percent of NaN value: 0.00
# column: Name	 Percent of NaN value: 0.00
# column: Sex	 Percent of NaN value: 0.00
# column: Age	 Percent of NaN value: 19.87
# column: SibSp	 Percent of NaN value: 0.00
# column: Parch	 Percent of NaN value: 0.00
# column: Ticket	 Percent of NaN value: 0.00
# column: Fare	 Percent of NaN value: 0.00
# column: Cabin	 Percent of NaN value: 77.10
# column: Embarked	 Percent of NaN value: 0.22

# %% [markdown]
# ## test set

# %%
for col in df_test.columns:
    percent=100*(df_test[col].isnull().sum()/df_test[col].shape[0])
    msg="column: {}\t Percent of NaN value: {:.2f}".format(col,percent)
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00
# column: Pclass	 Percent of NaN value: 0.00
# column: Name	 Percent of NaN value: 0.00
# column: Sex	 Percent of NaN value: 0.00
# column: Age	 Percent of NaN value: 20.57
# column: SibSp	 Percent of NaN value: 0.00
# column: Parch	 Percent of NaN value: 0.00
# column: Ticket	 Percent of NaN value: 0.00
# column: Fare	 Percent of NaN value: 0.24
# column: Cabin	 Percent of NaN value: 78.23
# column: Embarked	 Percent of NaN value: 0.00

# %% [markdown]
# # Target check (for imbalance, etc)

# %%
fig,axs=plt.subplots(1,2,figsize=(18,8))

df_train["Survived"].value_counts().plot.pie(ax=axs[0])
sns.countplot("Survived",data=df_train,ax=axs[1])

# %%
print(df_train.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Categorize features

# %%
Categorical_features=["Survived","Pclass","Sex","SibSp","Parch","Embarked"]
## small number of features
Number_features=["Age","Fare"]
## Continuous or discrete but many integers of floats
Many_Categorical_features=["Name","PassengerId","Ticket","Cabin"]
## Many number of features not Number_features

# %% [markdown]
# # Single feature distribution

# %%
def single_distrib(feature_name,ax,df,hue=None):
    ## countplot
    y=sns.countplot(x=feature_name,data=df,ax=ax,hue=hue)
    ax.set_title(feature_name)
    y.set_xticklabels(y.get_xticklabels(),rotation=45)
    
def plot_single_distrib(df,feature_list,row=1,col=1,figsize=(13,8),hue=None):
    fig,ax = plt.subplots(row,col,figsize=figsize)
    if row == 1 and col == 1:
        for feature in feature_list:
            single_distrib(feature,ax,df,hue)
            
    elif row == 1 and col != 1:
        for jmi,feature in enumerate(feature_list):
            single_distrib(feature,ax[jmi],df,hue)
    else:
        for jmi,feature in enumerate(feature_list):
            widx,hidx=divmod(jmi,col)
            single_distrib(feature,ax[widx][hidx],df,hue)

# %%
feature_list=Categorical_features+Number_features
plot_single_distrib(df_train,feature_list,4,2,(15,30))

# %%
feature_list=Categorical_features+Number_features
plot_single_distrib(df_train,feature_list,4,2,(15,30),"Survived")

# %%
df_train[["Pclass","Survived"]].groupby(["Pclass"],as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'],df_train['Survived'],margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
# feature_list=["Pclass","Survived"]
# plot_single_distrib(df_train,feature_list,2,1,(20,15))

# %%
fname="PassengerId"
# fig,ax=plt.subplots(1,1,figsize=(13,8))
# sns.catplot(x=fname,kind="count",data=df_train,ax=ax)
# ax.set_title(fname)

# %%
fig,ax=plt.subplots(1,1,figsize=(13,8))
sns.scatterplot(x="Age",y="Fare",hue="Embarked",size="Survived",data=df_train,ax=ax)

# %% [markdown]
# # Important Features
# 1. Fare
# 2. Pclass
# 3. Sex
# 4.

# %%
#fig,ax=plt.subplots(1,1,figsize=(15,15))
#sns.pairplot(df_train[Number_features+["Survived"]])
#sns.pairplot(df_test[Number_features])

# %%
# fig,ax=plt.subplots(1,1,figsize=(13,8))
# sns.catplot(x="Pclass",y="Fare",hue="Survived",kind="violin",innter="stick",split=True,palette="pastel",data=df_train,ax=ax)

# %% [markdown]
# 1. Define Problem.
# 2. Null data check & Categorization of features
#     * Categorical Features (Discrete and small kinds)
#     * Continuous Features
#     * Unspecified Featues (Discrete and many kinds)
# 2. Single feature distribution
# 3. Single feature distribution with respect to Object Feature
# 4. Double features distribution +three + four
#
# 5. during [2-4] select important features!
# 6. Naive test with logistic regression, or appropriate model and grid search!
# 7. Confusion Mtx analysis
# 8. feature engineering in Unspecified Features
# 9. adding the data and [6-8 loop]
# 10. Fine featuring revision and model selection with grid search!
# 11. Again and Again
# 12. semisupervised

# %% [markdown]
# # Cabin

# %%
def first_letter(word):
    if type(word) == str:
        return word[0]
    else: return np.nan

# %%
df_train["Cabin"].head()
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
a=df_train["Cabin"].apply(first_letter)
a.head()
# Out:
# 0    NaN
# 1      C
# 2    NaN
# 3      C
# 4    NaN
# Name: Cabin, dtype: object

# %% [markdown]
# # Ticket

# %%
t_df=df_train[["Ticket","Survived"]].groupby(["Ticket"]).count()
print(len(t_df))
print(len(df_train))
# Out:
# 681
# 891

# %%
def prefix(word):
    a=word.split()
    if a[0].isdecimal():
        return 1
    else:return a[0]

# %%
Ticket=df_train["Ticket"].apply(prefix)
Ticket.head()
# Out:
# 0         A/5
# 1          PC
# 2    STON/O2.
# 3           1
# 4           1
# Name: Ticket, dtype: object

# %%
TT=pd.concat([Ticket,df_train["Survived"]],axis=1)
# TT.groupby(["Ticket"]).count()
pd.crosstab(Ticket,df_train["Survived"])
# Out:
# Survived      0    1
# Ticket
# 1           407  254
# A./5.         2    0
# A.5.          2    0
# A/4           3    0
# A/4.          3    0
# A/5           9    1
# A/5.          6    1
# A/S           1    0
# A4.           1    0
# C             3    2
# C.A.         14   13
# C.A./SOTON    1    0
# CA            6    0
# CA.           7    1
# F.C.          1    0
# F.C.C.        1    4
# Fa            1    0
# LINE          3    1
# P/PP          1    1
# PC           21   39
# PP            1    2
# S.C./A.4.     1    0
# S.C./PARIS    1    1
# S.O./P.P.     3    0
# S.O.C.        5    0
# S.O.P.        1    0
# S.P.          1    0
# S.W./PP       0    1
# SC            0    1
# SC/AH         1    2
# SC/PARIS      3    2
# SC/Paris      2    2
# SCO/W         1    0
# SO/C          0    1
# SOTON/O.Q.    7    1
# SOTON/O2      2    0
# SOTON/OQ      6    1
# STON/O        7    5
# STON/O2.      3    3
# SW/PP         0    1
# W./C.         8    1
# W.E.P.        1    0
# W/C           1    0
# WE/P          1    1

# %% [markdown]
# # Name

# %%
df_train[df_train["Age"]<10][["Name","Age"]].head(10)
# Out:
#                                          Name   Age
# 7              Palsson, Master. Gosta Leonard  2.00
# 10            Sandstrom, Miss. Marguerite Rut  4.00
# 16                       Rice, Master. Eugene  2.00
# 24              Palsson, Miss. Torborg Danira  8.00
# 43   Laroche, Miss. Simonne Marie Anne Andree  3.00
# 50                 Panula, Master. Juha Niilo  7.00
# 58               West, Miss. Constance Mirium  5.00
# 63                      Skoog, Master. Harald  4.00
# 78              Caldwell, Master. Alden Gates  0.83
# 119         Andersson, Miss. Ellis Anna Maria  2.00

# %%
s="Cornelii, Mr. Son"
s1=s.split(", ")
s2=s1[1].split(".")
s2[0]
# Out:
# 'Mr'

# %%
title_list=["Mr","Mrs","Master","Miss"]
def title_processor(word):
    s1=word.split(", ")
    s2=s1[1].split(".")
    if not s2[0] in title_list:
        return "Others"
    return s2[0]

# %%
titles=df_train["Name"].apply(title_processor)
titles.head(20)
pd_title_test=pd.concat([titles,df_train["Survived"]],axis=1)

# %%
pd_title_test.groupby(["Name"]).count()
# Out:
#         Survived
# Name
# Master        40
# Miss         182
# Mr           517
# Mrs          125
# Others        27

# %%
test_titles=df_test["Name"].apply(title_processor)
pd_title_=pd.concat([test_titles,df_test["Sex"]],axis=1)
pd_title_.groupby(["Name"]).count()
# Out:
#         Sex
# Name
# Master   21
# Miss     78
# Mr      240
# Mrs      72
# Others    7

# %% [markdown]
# # Modification data in Train & Test

# %%
features=["Pclass","Sex","SibSp","Parch","Embarked","Age","Fare","Name"]
# Cabin=df_train["Cabin"].apply(first_letter)
train_Name=
pdf_train=pd.concat([df_train[features],titles,df_train["Survived"]],axis=1)

# %%
pdf_train.head(5)
# Out:
#    Pclass     Sex  SibSp  Parch Embarked   Age     Fare  \
# 0       3    male      1      0        S  22.0   7.2500
# 1       1  female      1      0        C  38.0  71.2833
# 2       3  female      0      0        S  26.0   7.9250
# 3       1  female      1      0        S  35.0  53.1000
# 4       3    male      0      0        S  35.0   8.0500
#
#                                                 Name  Name  Survived
# 0                            Braund, Mr. Owen Harris    Mr         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Mrs         1
# 2                             Heikkinen, Miss. Laina  Miss         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Mrs         1
# 4                           Allen, Mr. William Henry    Mr         0

# %%
# plot_single_distrib(pdf_train,["Cabin","Ticket","Name","Embarked"],2,2,(8,8))

# %% [markdown]
# # Fill in Null data (Cabin, Age, and exceptionally Fare in Test dataset)

# %%
pdf_train.columns

# %%
# pd.crosstab(pdf_train["Cabin"],pdf_train["Survived"],margins=True)

# %%
# sns.countplot(x="Cabin",data=b,hue="Survived")
# pd.crosstab(b["Ticket"],b["Survived"])

# %%
# mpdf_train=pdf_train.drop(["Cabin"],axis=1)

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan, strategy="most_frequent")
imp2=SimpleImputer(missing_values=np.nan, strategy="most_frequent")
pdf_train.loc[:,["Embarked","Age"]]=imp.fit_transform(pdf_train[["Embarked","Age"]])

# %%
for col in pdf_train.columns:
    percent=100*(pdf_train[col].isnull().sum()/pdf_train[col].shape[0])
    msg="column: {}\t Percent of NaN value: {:.2f}".format(col,percent)
    print(msg)

# %% [markdown]
# # Analysis

# %% [markdown]
# # One-hot encoding

# %%
pdf_train=pd.get_dummies(pdf_train,columns=["Sex","Embarked"])

# %%
pdf_train.head()

# %% [markdown]
# # Test dataset

# %%
Cabin_test=df_test["Cabin"].apply(first_letter)
Ticket_test=df_test["Ticket"].apply(prefix)
titles_test=df_test["Name"].apply(title_processor)
features_test=["Pclass","Sex","SibSp","Parch","Embarked"]+["Age","Fare"]
pdf_test=pd.concat([df_test[features_test]],axis=1)

# %%
pdf_test.loc[:,["Embarked","Age"]]=imp.transform(pdf_test[["Embarked","Age"]])

# %%
pdf_test.loc[:,["Fare"]]=imp2.fit_transform(pdf_test[["Fare"]])

# %%
pdf_test=pd.get_dummies(pdf_test,columns=["Sex","Embarked"])

# %%
pdf_train.columns

# %%
pdf_test.columns

# %%
for col in pdf_test.columns:
    percent=100*(pdf_test[col].isnull().sum()/pdf_test[col].shape[0])
    msg="column: {}\t Percent of NaN value: {:.2f}".format(col,percent)
    print(msg)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split

from sklearn.model_selection import cross_val_score

# %%
X_train=pdf_train.drop("Survived",axis=1).values
y_train=pdf_train["Survived"].values
X_test=pdf_test.values

# %%
X_tr,X_vld,y_tr,y_vld=train_test_split(X_train,y_train,test_size=0.2)

# %%
RF=RandomForestClassifier()

# %% [markdown]
# # Basic Cross Validation

# %%
scores=cross_val_score(RF,X_tr,y_tr,cv=5)
scores

# %% [markdown]
# # Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
    "n_estimators":[50,70,90,110,130],
    "max_depth":[5,7,9,11,13]
}

# %%
grid_search=GridSearchCV(RF,param_grid,cv=5)

# %%
grid_search.fit(X_tr,y_tr)

# %%
grid_search.score(X_tr,y_tr)

# %%
submission=pd.read_csv("./data/gender_submission.csv")

# %%
prediction=grid_search.predict(X_test)
submission["Survived"]=prediction

# %%
submission.to_csv('./my_first_submission.csv', index=False)
